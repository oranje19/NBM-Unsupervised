# %%
import pandas as pd
import nltk

# %%
reviews = pd.read_csv('dataset/small_corpus.csv')
# Out:
# /Users/jasonwintery/opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
reviews.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      1.0      True  12 25, 2015   ABKWZO2J7RB5C  B00X6ZUZME
# 1      1.0      True   08 8, 2016  A1BQU8JLXS6OOX  B015YE7SM4
# 2      1.0     False  02 17, 2011  A2Z6E2JHMTJJR4  B001CD8L1Y
# 3      1.0      True   01 4, 2018  A2Y3RL6NN4CI9D  B00CAUTK0E
# 4      1.0     False  09 17, 2010  A25HX4LNZLJNWD  B002BS47TE
#
#       reviewerName                                         reviewText  \
# 0     Jon.M.Barter  Weak sauce accessory.  Had to hold down button...
# 1  Richy Fukushima  I got this mouse on sale.  It looks nice, has ...
# 2             Heez  I bought this product from a different website...
# 3    Mason Rickert  Way overpriced. Hurt with a headset on. And wa...
# 4        mazinger4  I purchased this game over a month ago, and ev...
#
#                                              summary  unixReviewTime vote  \
# 0     There sare definitely better options out there      1451001600  NaN
# 1              nice product, but it freezes randomly      1470614400  NaN
# 2                                     Piece of junk.      1297900800  NaN
# 3  Overpriced, save your money and find a better,...      1515024000    2
# 4                      Boss difficulty is unbeatable      1284681600    4
#
#                                                style image
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# 3  {'Color:': ' Onyx', 'Style:': ' Standard Packa...   NaN
# 4                         {'Format:': ' Video Game'}   NaN

# %%
reviews.tail()
# Out:
#        overall  verified   reviewTime      reviewerID        asin  \
# 69995      5.0     False  08 28, 2007  A18RQ2URRGIIEA  B000O5TJTE
# 69996      5.0      True  11 27, 2016  A3SN0K4X6ON6FN  B01GWGXBV0
# 69997      5.0     False  04 18, 2011  A2HD3FQD7QL19K  B002BSA3EM
# 69998      5.0      True  03 31, 2014  A22JAEOWB0BBII  B00ECOBFA4
# 69999      5.0      True  07 21, 2012   ADC5AQV9HWN9P  B00006C28X
#
#       reviewerName                                         reviewText  \
# 69995      M. Hart  Having played each of the various video games ...
# 69996     DORNELLE                            Great!!! Work perfectly
# 69997        Patty  There are so many various games and workouts t...
# 69998    starlakai  My kids love this game! My 4 year old son and ...
# 69999          ant  Great Game For playstation 2 . Very fast shipp...
#
#                                                  summary  unixReviewTime  \
# 69995  A Fun, Challenging, Goal-Oriented & Character-...      1188259200
# 69996                                         Five Stars      1480204800
# 69997                               Fun way to work out!      1303084800
# 69998                                          Cool game      1396224000
# 69999                                      Great Game!!!      1342828800
#
#        vote                                              style image
# 69995  21.0                         {'Platform:': ' Xbox 360'}   NaN
# 69996   NaN  {'Edition:': ' Standard', 'Platform:': ' Ninte...   NaN
# 69997   NaN                                                NaN   NaN
# 69998   NaN                         {'Format:': ' Video Game'}   NaN
# 69999   NaN                                                NaN   NaN

# %%
reviews.sample(10)
# Out:
#        overall  verified   reviewTime      reviewerID        asin  \
# 27628      2.0      True  01 10, 2014  A2OUQRS5YWXQ38  B00B3PDH5G
# 35640      3.0      True  11 21, 2016  A1S67OZ5HRDGH5  B00002STXL
# 5738       1.0      True  06 28, 2015   AR91UPIV2M7CS  B00HV2CMX8
# 29159      2.0      True  05 28, 2015  A3K8PI414CYZOB  B00O06ZN3O
# 33027      3.0      True  05 13, 2013   AJT510WEA1QHV  B000R3BLA8
# 58997      5.0      True  12 15, 2016  A3JW1MHTYJ79JA  B00ZPFLSGK
# 50934      5.0      True  06 11, 2018  A2RS953AP4F0YT  B01FZ884E0
# 66552      5.0      True  06 27, 2015   AWEF0M7XHTQD2  B00FAS1WDG
# 16421      1.0      True  08 31, 2016   A1EG13JJ6M22F  B00WW0D54E
# 57758      5.0     False   01 2, 2009  A11UXRR3ZBCPAB  B00104KJ4C
#
#           reviewerName                                         reviewText  \
# 27628           Justin  I bought this headset with a few expectations ...
# 35640  Amazon Customer                                             Thanks
# 5738            Tim T.  They stopped working only a couple of months a...
# 29159     DONT LIKE IT                                                 no
# 33027    Greesemonkey3  This game was ok and didn't get much better. I...
# 58997      Murat Roody  I used it since january 2016, I get any proble...
# 50934        Zekebob12  Great product for as cheap as it is. It's not ...
# 66552      alex galvan  I rate this a five star because it got here fa...
# 16421           Miguel  These 2400mAH batteries are horrible. They hel...
# 57758           Samier  I love playing Lego Indiana Jones with my two ...
#
#                                                  summary  unixReviewTime vote  \
# 27628                  Great Sound. Terrible Microphone.      1389312000    2
# 35640                                        Three Stars      1479686400  NaN
# 5738   They stopped working only a couple of months a...      1435449600  NaN
# 29159                                          Two Stars      1432771200  NaN
# 33027                                                Meh      1368403200  NaN
# 58997                                         Five Stars      1481760000  NaN
# 50934                               Great for the price.      1528675200  NaN
# 66552                        love this Microsoft product      1435363200  NaN
# 16421                          Worst purchase in awhile.      1472601600   60
# 57758                        Fun & Entreating for Family      1230854400  NaN
#
#                                  style image
# 27628                              NaN   NaN
# 35640                              NaN   NaN
# 5738                               NaN   NaN
# 29159                              NaN   NaN
# 33027  {'Platform:': ' PlayStation 3'}   NaN
# 58997                              NaN   NaN
# 50934             {'Color:': ' Black'}   NaN
# 66552                              NaN   NaN
# 16421                              NaN   NaN
# 57758       {'Format:': ' Video Game'}   NaN

# %%
from nltk.tokenize import TreebankWordTokenizer
from string import punctuation
import string

# %%
tb_tokenizer = TreebankWordTokenizer()

# %%
reviews['rev_text_lower'] = reviews['reviewText'].apply(lambda rev: str(rev)
                                                        .translate(str.maketrans('', '', punctuation))
                                                        .replace('<br />', ' ')
                                                        .lower())

# %%
reviews[['reviewText', 'rev_text_lower']].sample(5)
# Out:
#                                               reviewText  \
# 64012                                        a good gift
# 58481  one of the best toys I have in my home,paid fo...
# 5355   This game is worthless. When on the green you ...
# 51806  Great case! Arrived quickly -- even fits my ne...
# 27489               Played it once and then never again.
#
#                                           rev_text_lower
# 64012                                        a good gift
# 58481  one of the best toys i have in my homepaid for...
# 5355   this game is worthless when on the green you c...
# 51806  great case arrived quickly  even fits my new 3...
# 27489                played it once and then never again

# %%
reviews['tb_token'] = reviews['rev_text_lower'].apply(lambda rev: tb_tokenizer.tokenize(str(rev)))

# %%
reviews[['reviewText', 'tb_token']].sample(5)
# Out:
#                                               reviewText  \
# 45502  Installation quick and easy. Took 20 minutes a...
# 24636  no instructions and very unclear how to play a...
# 46946  arrived promptly and was exactly what was aske...
# 48517  It's somewhat ironic that this showed up for m...
# 51681  This gamepad on the surface looks and feels li...
#
#                                                 tb_token
# 45502  [installation, quick, and, easy, took, 20, min...
# 24636  [no, instructions, and, very, unclear, how, to...
# 46946  [arrived, promptly, and, was, exactly, what, w...
# 48517  [its, somewhat, ironic, that, this, showed, up...
# 51681  [this, gamepad, on, the, surface, looks, and, ...

# %%
from nltk.tokenize.casual import casual_tokenize

# %%
reviews['casual_tokens'] = reviews['rev_text_lower'].apply(lambda rev: casual_tokenize(str(rev)))

# %%
reviews[['reviewText', 'casual_tokens', 'tb_token']].sample(5)
# Out:
#                                               reviewText  \
# 4520   Was really a good game. My disc was too scratc...
# 41220  I would have given it a 3 star but it's one of...
# 11048                                         triggered.
# 64230  After several rows from other sellers I decide...
# 31944     Only the thin plate over the face is aluminum.
#
#                                            casual_tokens  \
# 4520   [was, really, a, good, game, my, disc, was, to...
# 41220  [i, would, have, given, it, a, 3, star, but, i...
# 11048                                        [triggered]
# 64230  [after, several, rows, from, other, sellers, i...
# 31944  [only, the, thin, plate, over, the, face, is, ...
#
#                                                 tb_token
# 4520   [was, really, a, good, game, my, disc, was, to...
# 41220  [i, would, have, given, it, a, 3, star, but, i...
# 11048                                        [triggered]
# 64230  [after, several, rows, from, other, sellers, i...
# 31944  [only, the, thin, plate, over, the, face, is, ...

# %% [markdown]
# Stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
reviews['tokens_stemmed'] = reviews['tb_token'].apply(lambda words: [stemmer.stem(word) for word in words])

# %%
reviews[['tb_token', 'tokens_stemmed']].sample(5)
# Out:
#                                                 tb_token  \
# 11555  [i, purchased, this, stick, with, the, knowled...
# 34444  [for, the, price, i, am, overall, pleased, the...
# 48275  [i, have, the, black, version, of, this, contr...
# 24932  [i, must, agree, with, ramair350s, review, i, ...
# 22353  [slips, everywhere, carpet, tile, wood, floory...
#
#                                           tokens_stemmed
# 11555  [i, purchas, thi, stick, with, the, knowledg, ...
# 34444  [for, the, price, i, am, overal, pleas, the, b...
# 48275  [i, have, the, black, version, of, thi, contro...
# 24932  [i, must, agre, with, ramair350, review, i, wa...
# 22353  [slip, everywher, carpet, tile, wood, flooryou...

# %% [markdown]
# Lemmatisation

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag

# %%
def penn_to_wn(tag):
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None

# %%
lemmatizer = WordNetLemmatizer()

def get_lemmas(tokens):
    lemmas = []
    for token in tokens:
        pos = penn_to_wn(pos_tag([token])[0][1])
        if pos:
            lemma = lemmatizer.lemmatize(token, pos)
            if lemma:
                lemmas.append(lemma)
    return lemmas

# %%
reviews['lemmas'] = reviews['tb_token'].apply(lambda tokens: get_lemmas(tokens))

# %%
reviews[['reviewText', 'tokens_stemmed', 'lemmas']].sample(5)
# Out:
#                                               reviewText  \
# 61345  This game arrived fast and exactly as describe...
# 24629  I'll start off by saying that this remote has ...
# 15754       Middle wheel stopped working after x6 months
# 31475  Bought this used and it came in rougher shape ...
# 326              Please refund my money.. it doesnt work
#
#                                           tokens_stemmed  \
# 61345  [thi, game, arriv, fast, and, exactli, as, des...
# 24629  [ill, start, off, by, say, that, thi, remot, h...
# 15754       [middl, wheel, stop, work, after, x6, month]
# 31475  [bought, thi, use, and, it, came, in, rougher,...
# 326         [pleas, refund, my, money, it, doesnt, work]
#
#                                                   lemmas
# 61345  [game, arrive, fast, exactly, described, absol...
# 24629  [ill, start, say, remote, have, good, feature,...
# 15754             [middle, wheel, stop, work, x6, month]
# 31475  [bought, use, come, rougher, shape, expect, de...
# 326                [please, refund, money, doesnt, work]

# %% [markdown]
# Sentiment

# %%
def get_sentiment_score(tokens):
    score = 0
    tags = pos_tag(tokens)
    for word, tag in tags:
        wn_tag = penn_to_wn(tag)
        if not wn_tag:
            continue
        synsets = wn.synsets(word, pos=wn_tag)
        if not synsets:
            continue
            
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        
        score += (swn_synset.pos_score() - swn_synset.neg_score())
        
    return score

# %%
swn.senti_synset(wn.synsets('perfect', wn.ADJ)[0].name()).pos_score()
# Out:
# 0.625

# %%
reviews['sentiment_score'] = reviews['lemmas'].apply(lambda tokens: get_sentiment_score(tokens))

# %%
reviews[['reviewText', 'lemmas', 'sentiment_score']].sample(5)
# Out:
#                                               reviewText  \
# 37044               Fun but not the best they have done.
# 21403                          Could not get it to work.
# 28800                                      way too quiet
# 39750  just disapointed to find out you have to go th...
# 23857  This was the most disappointing thing I have e...
#
#                                                   lemmas  sentiment_score
# 37044                         [fun, not, best, have, do]            0.500
# 21403                                   [not, get, work]           -0.500
# 28800                                  [way, too, quiet]           -0.625
# 39750  [just, disapointed, find, have, go, thru, alot...            0.875
# 23857  [be, most, disappoint, thing, i, have, ever, b...            2.625

# %%
reviews[['reviewText', 'lemmas', 'sentiment_score']].sample(10)
# Out:
#                                               reviewText  \
# 47262  I'm having a lot fun playing the game. I wish ...
# 36811  It's definitely a good game, but I was pretty ...
# 41721  Biggest draw back, you cannot save your game, ...
# 39204  good game but platform games are still provide...
# 59853                                    Great keyboard!
# 31913  Very long and completely functional, except it...
# 58541  Awesome and work great. I would recommend thes...
# 44921  3 games for 20 dollars is a good deal, but com...
# 63516  I love this "game".  It's a mixture of games t...
# 68964          Best mouse I've owned. Awesome price too.
#
#                                                   lemmas  sentiment_score
# 47262  [im, have, lot, fun, play, game, i, wish, wasn...            2.125
# 36811  [definitely, good, game, i, be, pretty, let, d...            4.375
# 41721  [big, draw, back, not, save, game, have, finis...           -2.250
# 39204  [good, game, platform, game, be, still, provid...            1.125
# 59853                                  [great, keyboard]            0.000
# 31913  [very, long, completely, functional, stop, wor...            1.000
# 58541        [awesome, work, great, i, recommend, gamer]            0.375
# 44921  [game, dollar, be, good, deal, compare, unchar...            1.125
# 63516  [i, love, game, mixture, game, require, keep, ...            1.250
# 68964       [best, mouse, ive, own, awesome, price, too]            1.375
